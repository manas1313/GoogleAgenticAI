# %%
import os
from kaggle_secrets import UserSecretsClient

try:
    GOOGLE_API_KEY = UserSecretsClient().get_secret("GOOGLE_API_KEY")
    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
    print("✅ Gemini API key setup complete.")
except Exception as e:
    print(
        f"🔑 Authentication Error: Please make sure you have added 'GOOGLE_API_KEY' to your Kaggle secrets. Details: {e}"
    )
# Out:
# ✅ Gemini API key setup complete.

# %%
from typing import Any, Dict

from google.adk.agents import Agent, LlmAgent
from google.adk.apps.app import App, EventsCompactionConfig
from google.adk.models.google_llm import Gemini
from google.adk.sessions import DatabaseSessionService
from google.adk.sessions import InMemorySessionService
from google.adk.runners import Runner
from google.adk.tools.tool_context import ToolContext
from google.genai import types
from google.adk.memory import InMemoryMemoryService
from google.adk.tools import load_memory, preload_memory

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %%
'''Helper function that manages a complete conversation session, 
handling session creation/retrieval, query processing, and response streaming. 
It supports both single queries and multiple queries in sequence.
'''
async def run_session(
    runner_instance: Runner,
    user_queries: list[str] | str = None,
    session_name: str = "default",
):
    print(f"\n ### Session: {session_name}")

    # Get app name from the Runner
    app_name = runner_instance.app_name

    # Attempt to create a new session or retrieve an existing one
    try:
        session = await session_service.create_session(
            app_name=app_name, user_id=USER_ID, session_id=session_name
        )
    except:
        session = await session_service.get_session(
            app_name=app_name, user_id=USER_ID, session_id=session_name
        )

    # Process queries if provided
    if user_queries:
        # Convert single query to list for uniform processing
        if type(user_queries) == str:
            user_queries = [user_queries]

        # Process each query in the list sequentially
        for query in user_queries:
            print(f"\nUser > {query}")

            # Convert the query string to the ADK Content format
            query = types.Content(role="user", parts=[types.Part(text=query)])

            # Stream the agent's response asynchronously
            async for event in runner_instance.run_async(
                user_id=USER_ID, session_id=session.id, new_message=query
            ):
                # Check if the event contains valid content
                if event.content and event.content.parts:
                    # Filter out empty or "None" responses before printing
                    if (
                        event.content.parts[0].text != "None"
                        and event.content.parts[0].text
                    ):
                        print(f"{MODEL_NAME} > ", event.content.parts[0].text)
    else:
        print("No queries!")


print("✅ Helper functions defined.")
# Out:
# ✅ Helper functions defined.

# %%
retry_config = types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504],  # Retry on these HTTP errors
)

# %%
# Stateful Agent

APP_NAME = "default"  # Application
USER_ID = "default"  # User
SESSION = "default"  # Session

MODEL_NAME = "gemini-2.5-flash-lite"


# Step 1: Create the LLM Agent
root_agent = Agent(
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    name="text_chat_bot",
    description="A text chatbot",  # Description of the agent's purpose
)

# Step 2: Set up Session Management
# InMemorySessionService stores conversations in RAM (temporary)
session_service = InMemorySessionService()

# Step 3: Create the Runner
runner = Runner(agent=root_agent, app_name=APP_NAME, session_service=session_service)

print("✅ Stateful agent initialized!")
print(f"   - Application: {APP_NAME}")
print(f"   - User: {USER_ID}")
print(f"   - Using: {session_service.__class__.__name__}")
# Out:
# ✅ Stateful agent initialized!
#    - Application: default
#    - User: default
#    - Using: InMemorySessionService

# %%
# Let's Test our stateful Agent

await run_session(
    runner,
    [
        "Hi, I am Manas! What is the capital of Australia?",
        "Hello! What is my name?",  
    ],
    "stateful-agentic-session",
)

# %%
# Retry 

await run_session(
    runner,
    ["What did I ask you about earlier?", "And remind me, what's my name?"],
    "stateful-agentic-session",
)  # Note, we are using same session name

# %% [markdown]
# # Persistent Sessions
# with DatabaseSessionService

# %%
# Create the same agent 
chatbot_agent = LlmAgent(
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    name="text_chat_bot",
    description="A text chatbot with persistent memory",
)

# SQLite database will be created automatically
db_url = "sqlite:///my_agent_data.db"  # Local SQLite file
session_service = DatabaseSessionService(db_url=db_url)

# Create a new runner with persistent storage
runner = Runner(agent=chatbot_agent, app_name=APP_NAME, session_service=session_service)

print("✅ Upgraded to persistent sessions!")
print(f"   - Database: my_agent_data.db")
print(f"   - Sessions will survive restarts!")
# Out:
# ✅ Upgraded to persistent sessions!
#    - Database: my_agent_data.db
#    - Sessions will survive restarts!

# %%
# Run with Session

await run_session(
    runner,
    ["Hi, I am Manas! What is the capital of India?", "Hello! What is my name?"],
    "test-db-session-01",
)

# %%
await run_session(
    runner,
    ["What is the capital of Odisa?", "Hello! What is my name?"],
    "test-db-session-01",
)
# Out:
#  ### Session: test-db-session-01
#
# User > What is the capital of Odisa?
# gemini-2.5-flash-lite >  The capital of Odisha is Bhubaneswar.
#
# User > Hello! What is my name?
# gemini-2.5-flash-lite >  You told me your name is Manas.

# %%
await run_session(
    runner, ["Hello! What is my name?"], "test-db-session-02"
)
# Out:
#  ### Session: test-db-session-02
#
# User > Hello! What is my name?
# gemini-2.5-flash-lite >  I do not have access to your personal information, including your name. I am a text chatbot, and my purpose is to assist you with your queries and engage in conversations. I do not store any personal data about the users I interact with.

# %%
# Read sqlite db to view how data is stored

import sqlite3

def check_data_in_db():
    with sqlite3.connect("my_agent_data.db") as connection:
        cursor = connection.cursor()
        result = cursor.execute(
            "select app_name, session_id, author, content from events"
        )
        print([_[0] for _ in result.description])
        for each in result.fetchall():
            print(each)


check_data_in_db()

# %%
# Clean up any existing database to start fresh (if Notebook is restarted)
import os

if os.path.exists("my_agent_data.db"):
    os.remove("my_agent_data.db")
print("✅ Cleaned up old database files")
# Out:
# ✅ Cleaned up old database files

# %% [markdown]
# # Context Compaction

# %%
# Define an app with Events Compaction
research_app_compacting = App(
    name="research_app_compacting",
    root_agent=chatbot_agent,
   
    events_compaction_config=EventsCompactionConfig(
        compaction_interval=3,  # Trigger compaction every 3 invocations
        overlap_size=1,  # Keep 1 previous turn for context
    ),
)

db_url = "sqlite:///my_agent_data.db" 
session_service = DatabaseSessionService(db_url=db_url)


research_runner_compacting = Runner(
    app=research_app_compacting, session_service=session_service
)


print("✅ Research App upgraded with Events Compaction!")
# Out:
# ✅ Research App upgraded with Events Compaction!
# /tmp/ipykernel_48/330455107.py:6: UserWarning: [EXPERIMENTAL] EventsCompactionConfig: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   events_compaction_config=EventsCompactionConfig(

# %%
# Turn 1
await run_session(
    research_runner_compacting,
    "What is the latest news about AI in healthcare?",
    "compaction_demo",
)

# Turn 2
await run_session(
    research_runner_compacting,
    "Are there any new developments in drug discovery?",
    "compaction_demo",
)

# Turn 3 - Compaction should trigger after this turn!
await run_session(
    research_runner_compacting,
    "Tell me more about the second development you found.",
    "compaction_demo",
)

# Turn 4
await run_session(
    research_runner_compacting,
    "Who are the main companies involved in that?",
    "compaction_demo",
)
# Out:
#  ### Session: compaction_demo
#
# User > What is the latest news about AI in healthcare?
# gemini-2.5-flash-lite >  Here's a summary of some of the latest news and trends in AI in healthcare:
#
# **Key Areas of Advancement & Focus:**
#
# *   **Drug Discovery and Development:** AI is dramatically accelerating the identification of new drug candidates, predicting their efficacy, and optimizing clinical trial designs. Companies are leveraging AI to analyze vast biological datasets, pinpoint potential targets, and even design novel molecules.
#     *   **Example:** Recent news often highlights AI platforms that have identified potential treatments for diseases like Alzheimer's or specific cancers in a fraction of the time traditional methods would take.
# *   **Diagnostic Imaging and Pathology:** AI algorithms are becoming increasingly adept at analyzing medical images (X-rays, CT scans, MRIs, pathology slides) to detect abnormalities, often with greater speed and accuracy than human review alone. This is particularly impactful in areas like radiology, ophthalmology, and dermatology.
#     *   **Example:** AI tools are being developed and deployed to flag potential cancerous lesions in mammograms or diabetic retinopathy in eye scans, assisting radiologists and ophthalmologists.
# *   **Personalized Medicine and Treatment:** AI is enabling more tailored treatment plans based on an individual's genetic makeup, lifestyle, and medical history. This moves healthcare away from a one-size-fits-all approach.
#     *   **Example:** AI is being used to predict which patients will respond best to certain cancer therapies or to personalize dosages of medications.
# *   **Predictive Analytics for Patient Risk:** AI models are being used to identify patients at high risk of developing certain conditions (e.g., sepsis, heart failure, hospital readmission) allowing for earlier intervention and preventative care.
#     *   **Example:** Hospitals are implementing AI systems that monitor patient data in real-time to predict the likelihood of deterioration, alerting clinical staff to intervene proactively.
# *   **Administrative Efficiency and Workflow Optimization:** Beyond direct patient care, AI is being used to streamline administrative tasks, reduce burnout among healthcare professionals, and improve operational efficiency within hospitals and clinics. This includes tasks like scheduling, billing, and documentation.
#     *   **Example:** AI-powered tools are being developed to automate medical coding, transcribe doctor-patient conversations, and manage appointment scheduling.
# *   **Generative AI for Content Creation and Education:** Generative AI is finding applications in creating medical summaries, drafting patient communication materials, and even developing training simulations for healthcare professionals.
#     *   **Example:** Tools that can summarize lengthy patient charts or generate educational materials on specific medical conditions are gaining traction.
#
# **Recent Developments and Trends:**
#
# *   **Increased Regulatory Scrutiny and Approval:** As AI tools become more prevalent, regulatory bodies like the FDA are actively developing frameworks for approving and monitoring AI-powered medical devices and software, ensuring their safety and efficacy.
# *   **Focus on Explainability and Trust:** There's a growing emphasis on making AI models more transparent and explainable ("explainable AI" or XAI) so that clinicians can understand *why* an AI made a particular recommendation, fostering trust and adoption.
# *   **Addressing Data Privacy and Security:** With the use of sensitive patient data, robust measures for privacy, security, and ethical data handling are paramount and constantly being refined.
# *   **Collaboration Between Tech Companies and Healthcare Providers:** We're seeing more partnerships between AI developers and hospitals, research institutions, and pharmaceutical companies to co-develop and deploy AI solutions.
# *   **AI for Mental Health:** AI is being explored for applications in mental health, including early detection of mental health conditions through analyzing speech patterns or text, and for providing chatbot-based support.
#
# **Challenges and Considerations:**
#
# *   **Data Bias:** AI models can perpetuate existing biases present in the data they are trained on, potentially leading to inequitable outcomes for certain patient populations.
# *   **Integration into Existing Workflows:** Successfully integrating AI tools into complex and often legacy healthcare IT systems can be challenging.
# *   **Ethical Implications:** Questions around accountability, decision-making autonomy, and the potential for job displacement remain important discussion points.
# *   **Cost and Accessibility:** Ensuring that AI-powered healthcare solutions are affordable and accessible to all is crucial for widespread adoption.
#
# **Where to Find More Information:**
#
# To stay up-to-date, I recommend following:
#
# *   **Major medical journals and publications:** (e.g., The Lancet, JAMA, Nature Medicine, NEJM)
# *   **Reputable tech news outlets focused on healthcare AI:** (e.g., Fierce Biotech, STAT News, MedCity News)
# *   **Conferences and industry reports:** (e.g., HIMSS, HLTH, reports from consulting firms like Deloitte, McKinsey, PwC)
# *   **Websites of regulatory bodies:** (e.g., FDA's digital health section)
#
# The field of AI in healthcare is evolving incredibly rapidly, so new breakthroughs and applications are constantly emerging!
#
#  ### Session: compaction_demo
#
# User > Are there any new developments in drug discovery?
# gemini-2.5-flash-lite >  Yes, there are **significant and ongoing new developments in drug discovery powered by AI**. It's one of the most exciting and rapidly advancing areas where AI is making a tangible impact.
#
# Here are some key trends and specific examples of new developments:
#
# **1. Accelerated Target Identification and Validation:**
#
# *   **AI analyzing massive multi-omics datasets:** AI can sift through genomic, proteomic, transcriptomic, and metabolomic data far faster and more comprehensively than humans. This helps identify novel biological targets (genes, proteins) that are implicated in diseases but might have been previously overlooked.
# *   **Predicting disease mechanisms:** AI models can help unravel complex biological pathways and predict how specific targets might influence disease progression, providing stronger justification for pursuing them.
#
# **2. Novel Molecule Design and Optimization (Generative AI):**
#
# *   **De novo drug design:** Generative AI models (like GANs, VAEs, and transformers) are being used to design entirely new molecular structures with desired properties (e.g., binding affinity to a target, good ADMET properties - absorption, distribution, metabolism, excretion, and toxicity). This moves beyond just screening existing libraries.
# *   **"In silico" screening at scale:** AI can rapidly screen virtual libraries of billions of compounds to identify promising candidates for a specific target, drastically reducing the time and cost of physical screening.
# *   **Optimizing existing drug candidates:** AI can suggest modifications to existing drug molecules to improve their efficacy, reduce side effects, or enhance their pharmacokinetic properties.
#
# **3. Predicting Drug Efficacy and Toxicity:**
#
# *   **In silico toxicology:** AI is being used to predict potential toxic side effects of drug candidates early in the development process, saving considerable time and resources by weeding out problematic molecules before expensive preclinical or clinical trials.
# *   **Predicting treatment response:** AI can analyze patient data (genomic, clinical) to predict which individuals are most likely to respond to a particular drug, paving the way for more personalized and effective treatments.
#
# **4. Streamlining Clinical Trials:**
#
# *   **Patient selection and stratification:** AI can help identify the most suitable patients for clinical trials based on specific criteria, leading to more efficient and successful trials.
# *   **Predicting trial outcomes:** AI models are being developed to predict the likelihood of success for clinical trials based on preclinical data and early trial results.
# *   **Analyzing real-world evidence (RWE):** AI can process vast amounts of RWE from electronic health records, wearables, and other sources to gain insights into drug effectiveness and safety in real-world settings.
#
# **Recent Notable Developments & Companies:**
#
# *   **Insilico Medicine:** This company has been a leader in using generative AI for drug discovery. They have advanced several AI-discovered drug candidates into clinical trials for conditions like Idiopathic Pulmonary Fibrosis (IPF) and COVID-19. They recently announced a successful preclinical study for an AI-discovered drug targeting Alzheimer's.
# *   **Recursion Pharmaceuticals:** They use AI and automation to map human cellular biology and discover new treatments. Their platform analyzes vast amounts of imaging data to identify disease signatures and potential drug candidates.
# *   **Atomwise:** Focuses on using deep learning for structure-based drug discovery, predicting how small molecules will bind to proteins.
# *   **BenevolentAI:** Leverages AI to analyze scientific literature, patents, and clinical trial data to identify novel drug targets and potential therapeutic applications.
# *   **Nvidia's Clara Discovery Platform:** While not a drug discovery company itself, Nvidia provides the computational power and AI frameworks that enable many drug discovery efforts. They are continuously developing tools for molecular dynamics, protein folding (like AlphaFold integration), and generative chemistry.
# *   **Partnerships:** Major pharmaceutical companies like Pfizer, Novartis, and AstraZeneca are increasingly forming partnerships with AI-driven drug discovery startups to leverage their technology.
#
# **Key AI Technologies Being Utilized:**
#
# *   **Deep Learning (especially Convolutional Neural Networks - CNNs, Recurrent Neural Networks - RNNs, and Graph Neural Networks - GNNs):** For image analysis, sequence analysis, and molecular property prediction.
# *   **Generative Adversarial Networks (GANs) and Variational Autoencoders (VAEs):** For designing novel molecular structures.
# *   **Natural Language Processing (NLP):** For extracting insights from scientific literature and clinical trial reports.
# *   **Reinforcement Learning:** For optimizing molecular properties through iterative design.
#
# In summary, AI is not just a buzzword in drug discovery; it's a transformative force that is fundamentally changing how new medicines are found, designed, and developed, leading to faster, more efficient, and potentially more effective therapies.
#
#  ### Session: compaction_demo
#
# User > Tell me more about the second development you found.
# gemini-2.5-flash-lite >  You're asking about the **"Novel Molecule Design and Optimization (Generative AI)"** development in drug discovery. This is a particularly exciting area because it represents a paradigm shift from finding existing molecules to *creating* new ones from scratch.
#
# Let me elaborate on this:
#
# **The Core Idea: Creating New Molecules, Not Just Finding Them**
#
# Traditionally, drug discovery involved:
# 1.  **High-throughput screening (HTS):** Testing vast libraries of existing chemical compounds (millions of them) against a disease target to see if any "hit" the target. This is like looking for a specific key in a huge box of pre-made keys.
# 2.  **Medicinal chemistry optimization:** Once a "hit" is found, chemists would then modify it to improve its properties.
#
# Generative AI flips this on its head. Instead of just searching for existing keys, it learns the principles of how keys *should* be made and then *designs* entirely new ones that are perfectly suited for the lock (the disease target).
#
# **How Generative AI Works in This Context:**
#
# 1.  **Learning the Rules of Chemistry:** Generative AI models are trained on massive datasets of known molecules and their properties. They learn the complex relationships between a molecule's structure (how its atoms are arranged) and its characteristics (e.g., how well it binds to a protein, its solubility, its stability, its potential toxicity). This is like teaching a computer the "grammar" of molecular design.
#
# 2.  **Designing "De Novo" Molecules:** Once trained, these models can be prompted to generate novel molecular structures. You essentially give the AI a set of requirements or constraints, such as:
#     *   "Design a molecule that binds strongly to this specific protein pocket."
#     *   "Design a molecule that has these functional groups, but avoid those that might cause toxicity."
#     *   "Design a molecule that is soluble in water and can be easily absorbed."
#
# 3.  **Iterative Optimization:** The AI can also be used in an iterative loop. It might design a molecule, then predict its properties. If those properties aren't perfect, the AI can then refine the molecule based on those predictions, generating a better version in the next round. This is like a sculptor refining a statue based on feedback.
#
# **Specific Techniques and Models Used:**
#
# *   **Generative Adversarial Networks (GANs):** These involve two neural networks – a "generator" that creates molecules and a "discriminator" that tries to distinguish between real, known molecules and the generated ones. This adversarial process pushes the generator to create increasingly realistic and promising molecules.
# *   **Variational Autoencoders (VAEs):** These models learn a compressed "latent space" representation of molecules. By manipulating points in this latent space, they can generate new molecules with desired characteristics.
# *   **Reinforcement Learning (RL):** Can be combined with generative models to guide the generation process towards molecules that meet specific optimization criteria (e.g., maximize binding affinity, minimize predicted toxicity).
# *   **Transformer Networks:** Originally used in natural language processing, these are now being adapted to molecular design, allowing them to capture long-range dependencies in molecular structures and sequences.
# *   **Graph Neural Networks (GNNs):** Molecules are inherently graphs (atoms are nodes, bonds are edges). GNNs are particularly well-suited for learning from and generating molecular graphs.
#
# **Why This is a Game-Changer:**
#
# *   **Vastly Expanded Chemical Space:** The number of possible molecules is astronomically large. Generative AI can explore this vast chemical space far more effectively than traditional methods, potentially uncovering entirely new classes of drugs that would never have been found otherwise.
# *   **Speed and Efficiency:** Designing molecules that were once the painstaking work of teams of chemists can now be done much faster, significantly accelerating the early stages of drug discovery.
# *   **Tailored Solutions:** AI can design molecules with specific, highly tailored properties for particular targets and patient populations, leading to more effective and safer drugs.
# *   **Overcoming "Undruggable" Targets:** Some disease targets are notoriously difficult to bind with small molecules using traditional approaches. Generative AI may be able to design novel structures that can interact with these challenging targets.
#
# **Examples of Impact:**
#
# *   **Insilico Medicine's Pipeline:** As mentioned before, they are a prime example. They have used their generative AI platform to design novel drug candidates for diseases like fibrosis and cancer, with some already progressing into human clinical trials. This demonstrates the translation from AI design to actual drug development.
# *   **Designing Novel Antibiotics:** Generative AI is being used to design new antibiotics that can overcome existing resistance mechanisms in bacteria.
#
# This "generative AI for molecule design" capability is truly at the cutting edge of AI in healthcare, pushing the boundaries of what's possible in creating life-saving medicines.
#
#  ### Session: compaction_demo
#
# User > Who are the main companies involved in that?
# gemini-2.5-flash-lite >  You're asking about the main players in the exciting field of **generative AI for novel molecule design and optimization in drug discovery**. This is a rapidly evolving space, so new companies emerge and existing ones expand their capabilities. However, here are some of the key companies and types of organizations that are making significant contributions:
#
# **1. Dedicated AI-First Drug Discovery Companies:**
#
# These companies were founded specifically with AI at their core and often focus heavily on generative approaches.
#
# *   **Insilico Medicine:** A pioneer in this space. They have a well-publicized generative AI platform that they use to identify targets, design novel molecules, and advance them into clinical trials. They are very transparent about their AI-driven approach.
# *   **Recursion Pharmaceuticals:** While their platform is broader, it heavily involves AI for generating insights and understanding biological systems, which in turn guides molecule design. They use AI to map cellular disease phenotypes and identify therapeutic interventions.
# *   **Atomwise:** Focuses on structure-based drug design using deep learning. They generate novel molecules that are predicted to bind strongly to specific protein targets.
# *   **Exscientia:** Uses AI to design and optimize molecules. They aim to automate and accelerate the entire drug discovery process, with a significant emphasis on designing novel compounds.
# *   **AbCellera:** While known for antibody discovery, they also leverage AI and machine learning, including generative approaches, to design and optimize therapeutic proteins and antibodies.
# *   **DeepMind (Google/Alphabet):** While not a drug discovery company itself, their work on **AlphaFold** has revolutionized protein structure prediction. This accurate structural information is a crucial input for many generative AI molecule design platforms, making them much more effective. Their ongoing research into AI for biological systems also has implications.
#
# **2. Big Pharma with Internal AI Capabilities & Partnerships:**
#
# Major pharmaceutical companies are heavily investing in AI, both by building internal teams and by partnering with AI-native companies.
#
# *   **Pfizer:** Has been actively investing in AI, including partnerships for AI-driven drug discovery. They are exploring generative models for designing novel small molecules.
# *   **Novartis:** A leader in adopting AI and machine learning. They have internal AI research divisions and collaborations aimed at accelerating drug design.
# *   **Roche/Genentech:** Actively uses AI for various aspects of drug discovery, including target identification and molecule generation.
# *   **AstraZeneca:** Has been very vocal about its AI strategy and has invested in AI-driven drug discovery platforms and partnerships.
# *   **Merck, Bristol Myers Squibb, Eli Lilly, Sanofi:** All have significant investments and ongoing projects in AI for drug discovery, including generative AI for molecule design.
#
# **3. AI/ML Technology Providers and Infrastructure Companies:**
#
# These companies provide the foundational tools, platforms, and computing power that enable generative AI in drug discovery.
#
# *   **Nvidia:** Crucial for providing the high-performance GPUs and AI software frameworks (like Clara Discovery) that are essential for training and running complex generative AI models for molecular simulations and design.
# *   **Google Cloud / Amazon Web Services / Microsoft Azure:** Provide the cloud computing infrastructure necessary for the massive data processing and model training required.
# *   **Specialized Software/Platform Providers:** Companies that offer AI platforms specifically tailored for cheminformatics, computational chemistry, and generative molecular design.
#
# **4. Academic and Research Institutions:**
#
# Universities and research labs are at the forefront of developing the underlying AI algorithms and methodologies that power generative drug discovery. Many of the foundational research papers originate from these institutions, and spin-off companies are often formed from academic breakthroughs.
#
# **Key Considerations When Looking at Companies:**
#
# *   **Stage of Development:** Some companies are focused on early-stage discovery, while others have molecules in preclinical or clinical development.
# *   **Therapeutic Area Focus:** Many companies specialize in specific disease areas (e.g., oncology, neurodegenerative diseases, rare diseases).
# *   **Breadth of Platform:** Some platforms are broad, covering target identification to molecule design, while others are highly specialized in generative chemistry.
# *   **Partnership Models:** How do these companies engage with pharmaceutical giants? Through licensing, co-development, or outright acquisition?
#
# The landscape is dynamic, with acquisitions, new funding rounds, and evolving technology. However, the companies listed above are consistently recognized as leaders pushing the boundaries of generative AI in creating the next generation of medicines.

# %%
# Get the final session state
final_session = await session_service.get_session(
    app_name=research_runner_compacting.app_name,
    user_id=USER_ID,
    session_id="compaction_demo",
)

print("--- Searching for Compaction Summary Event ---")
found_summary = False
for event in final_session.events:
    # Compaction events have a 'compaction' attribute
    if event.actions and event.actions.compaction:
        print("\n✅ SUCCESS! Found the Compaction Event:")
        print(f"  Author: {event.author}")
        print(f"\n Compacted information: {event}")
        found_summary = True
        break

if not found_summary:
    print(
        "\n❌ No compaction event found. Try increasing the number of turns in the demo."
    )
# Out:
# --- Searching for Compaction Summary Event ---
#
# ✅ SUCCESS! Found the Compaction Event:
#   Author: user
#
#  Compacted information: model_version=None content=None grounding_metadata=None partial=None turn_complete=None finish_reason=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=None live_session_resumption_update=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None invocation_id='c7c182b5-5889-4f22-b785-eed071b6ef47' author='user' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction={'start_timestamp': 1763928532.013636, 'end_timestamp': 1763928542.675884, 'compacted_content': {'parts': [{'function_call': None, 'code_execution_result': None, 'executable_code': None, 'file_data': None, 'function_response': None, 'inline_data': None, 'text': 'The user is asking about new developments in AI in drug discovery. The AI agent provided a comprehensive overview of the latest advancements, categorized by key areas and recent trends.\n\n**Key Areas of Advancement:**\n\n*   **Accelerated Target Identification and Validation:** AI is analyzing vast biological datasets to pinpoint novel disease targets.\n*   **Novel Molecule Design and Optimization (Generative AI):** AI is creating entirely new molecular structures with desired properties, moving beyond screening existing compounds.\n*   **Predicting Drug Efficacy and Toxicity:** AI is used for "in silico" toxicology and predicting treatment response.\n*   **Streamlining Clinical Trials:** AI aids in patient selection, stratification, and predicting trial outcomes.\n\n**Recent Trends and Developments:**\n\n*   **Companies and Technologies:** Specific companies like Insilico Medicine, Recursion Pharmaceuticals, Atomwise, and BenevolentAI are highlighted for their work. Nvidia\'s Clara Discovery Platform is also mentioned as an enabler.\n*   **AI Technologies Used:** Deep Learning, GANs, VAEs, NLP, and Reinforcement Learning are key technologies.\n*   **Impact:** AI is expanding the searchable chemical space, increasing speed and efficiency, enabling tailored drug solutions, and potentially addressing "undruggable" targets.\n\nThe conversation then focused specifically on **"Novel Molecule Design and Optimization (Generative AI)"**. The AI agent explained:\n\n*   **The Core Idea:** Generative AI creates new molecules rather than just finding existing ones.\n*   **How it Works:** Models learn chemical rules from data and are prompted to design molecules with specific requirements, often through iterative optimization.\n*   **Techniques:** GANs, VAEs, RL, Transformers, and GNNs are employed.\n*   **Significance:** This approach expands chemical space, speeds up discovery, allows for tailored solutions, and can tackle difficult targets.\n*   **Examples:** Insilico Medicine\'s clinical trial candidates and the design of new antibiotics are cited.\n\n**Unresolved Questions/Tasks:**\n\nThere are no unresolved questions or outstanding tasks from this interaction. The user\'s initial broad question was answered, and a follow-up request for more detail on a specific aspect was also fulfilled.', 'thought': None, 'thought_signature': None, 'video_metadata': None}], 'role': 'model'}}, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None) long_running_tool_ids=set() branch=None id='19b24133-f91c-4f98-afe6-3cf462dcd5cf' timestamp=1763928552.190321

# %%
# Clean up any existing database
import os

if os.path.exists("my_agent_data.db"):
    os.remove("my_agent_data.db")
print("✅ Cleaned up old database files")
# Out:
# ✅ Cleaned up old database files

# %% [markdown]
# # Session State

# %%
USER_NAME_SCOPE_LEVELS = ("temp", "user", "app")


# The 'user:' prefix indicates this is user-specific data.
def save_userinfo(
    tool_context: ToolContext, user_name: str, country: str
) -> Dict[str, Any]:
    """
    Tool to record and save user name and country in session state.

    Args:
        user_name: The username to store in session state
        country: The name of the user's country
    """
    # Write to session state using the 'user:' prefix for user data
    tool_context.state["user:name"] = user_name
    tool_context.state["user:country"] = country

    return {"status": "success"}


# How tools can read from session state.
def retrieve_userinfo(tool_context: ToolContext) -> Dict[str, Any]:
    """
    Tool to retrieve user name and country from session state.
    """
    # Read from session state
    user_name = tool_context.state.get("user:name", "Username not found")
    country = tool_context.state.get("user:country", "Country not found")

    return {"status": "success", "user_name": user_name, "country": country}


print("✅ Tools created.")
# Out:
# ✅ Tools created.

# %%
# Configuration
APP_NAME = "default"
USER_ID = "default"
MODEL_NAME = "gemini-2.5-flash-lite"

# Create an agent with session state tools
root_agent = LlmAgent(
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    name="text_chat_bot",
    description="""A text chatbot.
    Tools for managing user context:
    * To record username and country when provided use `save_userinfo` tool. 
    * To fetch username and country when required use `retrieve_userinfo` tool.
    """,
    tools=[save_userinfo, retrieve_userinfo],  # Provide the tools to the agent
)

# Set up session service and runner
session_service = InMemorySessionService()
runner = Runner(agent=root_agent, session_service=session_service, app_name="default")

print("✅ Agent with session state tools initialized!")
# Out:
# ✅ Agent with session state tools initialized!

# %%
# Test conversation demonstrating session state
await run_session(
    runner,
    [
        "Hi there, how are you doing today? What is my name?",  # Agent shouldn't know the name yet
        "My name is Manas. I'm from India.",  # Provide name - agent should save it
        "What is my name? Which country am I from?",  # Agent should recall from session state
    ],
    "state-demo-session",
)
# Out:
#  ### Session: state-demo-session
#
# User > Hi there, how are you doing today? What is my name?
# gemini-2.5-flash-lite >  Hello! I'm doing great, thank you for asking. I'm sorry, I don't have access to your name.
#
#
# User > My name is Manas. I'm from India.
# gemini-2.5-flash-lite >  It is nice to meet you, Manas! I have saved your information.
#
#
# User > What is my name? Which country am I from?
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# gemini-2.5-flash-lite >  I see that your name is Manas and you are from India.

# %%
# Retrieve the session and inspect its state
session = await session_service.get_session(
    app_name=APP_NAME, user_id=USER_ID, session_id="state-demo-session"
)

print("Session State Contents:")
print(session.state)
print("\n🔍 Notice the 'user:name' and 'user:country' keys storing our data!")
# Out:
# Session State Contents:
# {}
#
# 🔍 Notice the 'user:name' and 'user:country' keys storing our data!

# %%
# Start a completely new session - the agent won't know our name
await run_session(
    runner,
    ["Hi there, how are you doing today? What is my name?"],
    "new-isolated-session",
)
# Out:
#  ### Session: new-isolated-session
#
# User > Hi there, how are you doing today? What is my name?
# gemini-2.5-flash-lite >  Hello! I'm doing well, thank you for asking. I can't recall your name at the moment. Could you please tell me what it is?

# %%
# Check the state of the new session
session = await session_service.get_session(
    app_name=APP_NAME, user_id=USER_ID, session_id="new-isolated-session"
)

print("New Session State:")
print(session.state)

# Note: Depending on implementation, you might see shared state here.
# This is where the distinction between session-specific and user-specific state becomes important.
# Out:
# New Session State:
# {}

# %% [markdown]
# # Memory Management

# %% [markdown]
# **1. Session: They remember what you said 10 minutes ago in THIS conversation**
#
# **2. Memory: They remember your preferences from conversations LAST WEEK**

# %%
from google.adk.tools import load_memory, preload_memory

# %%
"""This helper function manages a complete conversation session, 
    handling session creation/retrieval, query processing, and response streaming."""

async def run_session(
    runner_instance: Runner, user_queries: list[str] | str, session_id: str = "default"
):
    """Helper function to run queries in a session and display responses."""
    print(f"\n### Session: {session_id}")

    # Create or retrieve session
    try:
        session = await session_service.create_session(
            app_name=APP_NAME, user_id=USER_ID, session_id=session_id
        )
    except:
        session = await session_service.get_session(
            app_name=APP_NAME, user_id=USER_ID, session_id=session_id
        )

    # Convert single query to list
    if isinstance(user_queries, str):
        user_queries = [user_queries]

    # Process each query
    for query in user_queries:
        print(f"\nUser > {query}")
        query_content = types.Content(role="user", parts=[types.Part(text=query)])

        # Stream agent response
        async for event in runner_instance.run_async(
            user_id=USER_ID, session_id=session.id, new_message=query_content
        ):
            if event.is_final_response() and event.content and event.content.parts:
                text = event.content.parts[0].text
                if text and text != "None":
                    print(f"Model: > {text}")


print("✅ Helper functions defined.")
# Out:
# ✅ Helper functions defined.

# %% [markdown]
# . InMemoryMemoryService - Built-in service for prototyping and testing (keyword matching, no persistence)
#
# . VertexAiMemoryBankService - Managed cloud service with LLM-powered consolidation and semantic search

# %%
# ADK's built-in Memory Service for development and testing
#Initialize Memory 
memory_service = (
    InMemoryMemoryService()
)

# %%
#Add Memory Agent

# Define constants used throughout the notebook
APP_NAME = "MemoryDemoApp"
USER_ID = "demo_user"

# Create agent
user_agent = LlmAgent(
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    name="MemoryDemoAgent",
    instruction="Answer user questions in simple words.",
)

print("✅ Agent created")
# Out:
# ✅ Agent created

# %%
# Create Session Service
session_service = InMemorySessionService()  # Handles conversations

# Create runner with BOTH services
runner = Runner(
    agent=user_agent,
    app_name="MemoryDemoApp",
    session_service=session_service,
    memory_service=memory_service,  # Memory service is now available!
)

print("✅ Agent and Runner created with memory support!")
# Out:
# ✅ Agent and Runner created with memory support!

# %%
# User tells agent about their favorite color
await run_session(
    runner,
    "My favorite color is blue-green. Can you write a Haiku about it?",
    "conversation-01",  # Session ID
)
# Out:
# ### Session: conversation-01
#
# User > My favorite color is blue-green. Can you write a Haiku about it?
# Model: > A calming ocean,
# Or leaves on a dewy branch,
# Nature's gentle hue.

# %%
#to  varify conversion is captured in session

session = await session_service.get_session(
    app_name=APP_NAME, user_id=USER_ID, session_id="conversation-01"
)

# Let's see what's in the session
print("📝 Session contains:")
for event in session.events:
    text = (
        event.content.parts[0].text[:60]
        if event.content and event.content.parts
        else "(empty)"
    )
    print(f"  {event.content.role}: {text}...")
# Out:
# 📝 Session contains:
#   user: My favorite color is blue-green. Can you write a Haiku about...
#   model: A calming ocean,
# Or leaves on a dewy branch,
# Nature's gentle...

# %%
# Now transfer it to memory.

# This is the key method!
await memory_service.add_session_to_memory(session)

print("✅ Session added to memory!")
# Out:
# ✅ Session added to memory!

# %% [markdown]
# You've successfully transferred session data to memory, but there's one crucial step remaining. Agents can't directly access the MemoryService - they need tools to search it.
#
# This is by design: it gives you control over when and how memory is retrieved.
#
#
# ADK provides two built-in tools for memory retrieval:
#
# 1. load_memory (Reactive)
#         Agent decides when to search memory
#         Only retrieves when the agent thinks it's needed
#         More efficient (saves tokens)
#         Risk: Agent might forget to search
# 2. preload_memory (Proactive)
#         Automatically searches before every turn
#         Memory always available to the agent
#         Guaranteed context, but less efficient
#         Searches even when not needed
#
# Think of it like studying for an exam: load_memory is looking things up only when you need them, while preload_memory is reading all your notes before answering each question.

# %%
# Load Memory

# Create agent
user_agent = LlmAgent(
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    name="MemoryDemoAgent",
    instruction="Answer user questions in simple words. Use load_memory tool if you need to recall past conversations.",
    tools=[
        load_memory
    ],  # Agent now has access to Memory and can search it whenever it decides to!
)

print("✅ Agent with load_memory tool created.")
# Out:
# ✅ Agent with load_memory tool created.

# %%
# Create a new runner with the updated agent
runner = Runner(
    agent=user_agent,
    app_name=APP_NAME,
    session_service=session_service,
    memory_service=memory_service,
)

await run_session(runner, "What is my favorite color?", "color-test")
# Out:
# ### Session: color-test
#
# User > What is my favorite color?
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.

# %%
await run_session(runner, "My birthday is on March 13th.", "birthday-session-01")
# Out:
# ### Session: birthday-session-01
#
# User > My birthday is on March 13th.
# Model: > Okay, I will remember that your birthday is on March 13th.

# %%
# Manually save the session to memory
birthday_session = await session_service.get_session(
    app_name=APP_NAME, user_id=USER_ID, session_id="birthday-session-01"
)

await memory_service.add_session_to_memory(birthday_session)

print("✅ Birthday session saved to memory!")
# Out:
# ✅ Birthday session saved to memory!

# %%
# Test retrieval in a NEW session
await run_session(
    runner, "When is my birthday?", "birthday-session-02"  # Different session ID
)
# Out:
# ### Session: birthday-session-02
#
# User > When is my birthday?
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Model: > Your birthday is on March 13th.

# %% [markdown]
# **Memory Search**
#
# Debugging memory contents
#
# Building analytics dashboards
#
# Creating custom memory management UIs
#
# The search_memory() method takes a text query and returns a SearchMemoryResponse with matching memories.

# %%
# Search for color preferences
search_response = await memory_service.search_memory(
    app_name=APP_NAME, user_id=USER_ID, query="What is the user's favorite color?"
)

print("🔍 Search Results:")
print(f"  Found {len(search_response.memories)} relevant memories")
print()

for memory in search_response.memories:
    if memory.content and memory.content.parts:
        text = memory.content.parts[0].text[:80]
        print(f"  [{memory.author}]: {text}...")
# Out:
# 🔍 Search Results:
#   Found 4 relevant memories
#
#   [user]: My favorite color is blue-green. Can you write a Haiku about it?...
#   [MemoryDemoAgent]: A calming ocean,
# Or leaves on a dewy branch,
# Nature's gentle hue....
#   [user]: My birthday is on March 13th....
#   [MemoryDemoAgent]: Okay, I will remember that your birthday is on March 13th....

# %% [markdown]
# # Automating Memory Storage

# %%
# Auto save memory call back
async def auto_save_to_memory(callback_context):
    """Automatically save session to memory after each agent turn."""
    await callback_context._invocation_context.memory_service.add_session_to_memory(
        callback_context._invocation_context.session
    )


print("✅ Callback created.")
# Out:
# ✅ Callback created.

# %%
# Agent with automatic memory saving
auto_memory_agent = LlmAgent(
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    name="AutoMemoryAgent",
    instruction="Answer user questions.",
    tools=[preload_memory],
    after_agent_callback=auto_save_to_memory,  # Saves after each turn!
)

print("✅ Agent created with automatic memory saving!")
# Out:
# ✅ Agent created with automatic memory saving!

# %%
# Create a runner for the auto-save agent
# This connects our automated agent to the session and memory services
auto_runner = Runner(
    agent=auto_memory_agent,  # Use the agent with callback + preload_memory
    app_name=APP_NAME,
    session_service=session_service,  # Same services from Section 3
    memory_service=memory_service,
)

print("✅ Runner created.")
# Out:
# ✅ Runner created.

# %%
# Test 1: Tell the agent about a gift (first conversation)
# The callback will automatically save this to memory when the turn completes
await run_session(
    auto_runner,
    "I gifted a new toy to my daughter on her 1st birthday!",
    "auto-save-test",
)

# Test 2: Ask about the gift in a NEW session (second conversation)
# The agent should retrieve the memory using preload_memory and answer correctly
await run_session(
    auto_runner,
    "What did I gift my daughter?",
    "auto-save-test-2",  # Different session ID - proves memory works across sessions!
)
# Out:
# ### Session: auto-save-test
#
# User > I gifted a new toy to my daughter on her 1st birthday!
# Model: > That's wonderful! A 1st birthday is such a special milestone. I hope your daughter loves her new toy!
#
# ### Session: auto-save-test-2
#
# User > What did I gift my daughter?
# Model: > You gifted your daughter a new toy.

# %% [markdown]
# # Memory Consolidation
