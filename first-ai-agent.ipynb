# %%
pip install google-adk

# %%
import os
from kaggle_secrets import UserSecretsClient

try:
    GOOGLE_API_KEY = UserSecretsClient().get_secret("GOOGLE_API_KEY")
    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
    print("✅ Gemini API key setup complete.")
except Exception as e:
    print(
        f"🔑 Authentication Error: Please make sure you have added 'GOOGLE_API_KEY' to your Kaggle secrets. Details: {e}"
    )
# Out:
# ✅ Gemini API key setup complete.

# %%
from google.adk.agents import Agent, SequentialAgent, ParallelAgent, LoopAgent, LlmAgent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.sessions import InMemorySessionService
from google.adk.tools import google_search, AgentTool, FunctionTool, ToolContext
from google.genai import types
from google.adk.code_executors import BuiltInCodeExecutor

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %%
# Helper functions
from IPython.core.display import display, HTML
from jupyter_server.serverapp import list_running_servers


# Gets the proxied URL in the Kaggle Notebooks environment
def get_adk_proxy_url():
    PROXY_HOST = "https://kkb-production.jupyter-proxy.kaggle.net"
    ADK_PORT = "8000"

    servers = list(list_running_servers())
    if not servers:
        raise Exception("No running Jupyter servers found.")

    baseURL = servers[0]["base_url"]

    try:
        path_parts = baseURL.split("/")
        kernel = path_parts[2]
        token = path_parts[3]
    except IndexError:
        raise Exception(f"Could not parse kernel/token from base URL: {baseURL}")

    url_prefix = f"/k/{kernel}/{token}/proxy/proxy/{ADK_PORT}"
    url = f"{PROXY_HOST}{url_prefix}"

    styled_html = f"""
    <div style="padding: 15px; border: 2px solid #f0ad4e; border-radius: 8px; background-color: #fef9f0; margin: 20px 0;">
        <div style="font-family: sans-serif; margin-bottom: 12px; color: #333; font-size: 1.1em;">
            <strong>⚠️ IMPORTANT: Action Required</strong>
        </div>
        <div style="font-family: sans-serif; margin-bottom: 15px; color: #333; line-height: 1.5;">
            The ADK web UI is <strong>not running yet</strong>. You must start it in the next cell.
            <ol style="margin-top: 10px; padding-left: 20px;">
                <li style="margin-bottom: 5px;"><strong>Run the next cell</strong> (the one with <code>!adk web ...</code>) to start the ADK web UI.</li>
                <li style="margin-bottom: 5px;">Wait for that cell to show it is "Running" (it will not "complete").</li>
                <li>Once it's running, <strong>return to this button</strong> and click it to open the UI.</li>
            </ol>
            <em style="font-size: 0.9em; color: #555;">(If you click the button before running the next cell, you will get a 500 error.)</em>
        </div>
        <a href='{url}' target='_blank' style="
            display: inline-block; background-color: #1a73e8; color: white; padding: 10px 20px;
            text-decoration: none; border-radius: 25px; font-family: sans-serif; font-weight: 500;
            box-shadow: 0 2px 5px rgba(0,0,0,0.2); transition: all 0.2s ease;">
            Open ADK Web UI (after running cell below) ↗
        </a>
    </div>
    """

    display(HTML(styled_html))

    return url_prefix


print("✅ Helper functions defined.")
# Out:
# ✅ Helper functions defined.

# %%
# Configure Retry Options

retry_config=types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1, # Initial delay before first retry (in seconds)
    http_status_codes=[429, 500, 503, 504] # Retry on these HTTP errors
)

# %%
root_agent = Agent(
    name="helpful_assistant",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    description="A simple agent that can answer general questions.",
    instruction="You are a helpful assistant. Use Google Search for current info or if unsure.",
    tools=[google_search],
)

print("✅ Root Agent defined.")
# Out:
# ✅ Root Agent defined.

# %%
runner = InMemoryRunner(agent=root_agent)

print("✅ Runner created.")
# Out:
# ✅ Runner created.

# %%
response = await runner.run_debug(
    "What is Agent Development Kit from Google? What languages is the SDK available in?"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > What is Agent Development Kit from Google? What languages is the SDK available in?
# helpful_assistant > The Google Agent Development Kit (ADK) is a flexible and modular open-source framework designed to simplify the development and deployment of AI agents and multi-agent systems. It aims to make agent creation feel more like traditional software development, offering control and orchestration capabilities for complex workflows. The ADK is optimized for Google's Gemini models and ecosystem but is model-agnostic and compatible with other frameworks.
#
# The ADK SDK is available in the following programming languages:
# *   **Python**
# *   **Go**
# *   **Java**

# %%
response = await runner.run_debug("What's the weather in Bangalore?")
# Out:
#  ### Continue session: debug_session_id
#
# User > What's the weather in Bangalore?
# helpful_assistant > As of Sunday evening in Bangalore, it is cloudy with a temperature of 71°F (22°C). The humidity is around 95%, and it feels like 76°F (24°C). There is a 0% chance of rain.
#
# The forecast for the next few days indicates mostly cloudy to partly cloudy conditions with temperatures generally ranging from the low 60s°F to the high 70s°F. There is a small chance of rain, typically around 10-20%.

# %%
# Web UI for Demo
# !adk create sample-agent --model gemini-2.5-flash-lite --api_key $GOOGLE_API_KEY
# Out:
# Agent created in /kaggle/working/sample-agent:
# - .env
# - __init__.py
# - agent.py

# %%
url_prefix = get_adk_proxy_url()
# Out:
#     <div style="padding: 15px; border: 2px solid #f0ad4e; border-radius: 8px; background-color: #fef9f0; margin: 20px 0;">
#         <div style="font-family: sans-serif; margin-bottom: 12px; color: #333; font-size: 1.1em;">
#             <strong>⚠️ IMPORTANT: Action Required</strong>
#         </div>
#         <div style="font-family: sans-serif; margin-bottom: 15px; color: #333; line-height: 1.5;">
#             The ADK web UI is <strong>not running yet</strong>. You must start it in the next cell.
#             <ol style="margin-top: 10px; padding-left: 20px;">
#                 <li style="margin-bottom: 5px;"><strong>Run the next cell</strong> (the one with <code>!adk web ...</code>) to start the ADK web UI.</li>
#                 <li style="margin-bottom: 5px;">Wait for that cell to show it is "Running" (it will not "complete").</li>
#                 <li>Once it's running, <strong>return to this button</strong> and click it to open the UI.</li>
#             </ol>
#             <em style="font-size: 0.9em; color: #555;">(If you click the button before running the next cell, you will get a 500 error.)</em>
#         </div>
#         <a href='https://kkb-production.jupyter-proxy.kaggle.net/k/281240113/eyJhbGciOiJkaXIiLCJlbmMiOiJBMTI4Q0JDLUhTMjU2IiwidHlwIjoiSldUIn0..bUCXkGAoNpXXorbDWbwBOQ.vlG-q47nvbmp-Z-ieTaTO2eb_cgVAQ4X04Yj_eo5p76uM9fbsvkGvACwObxT0pcgDzahNAUY_ZIC7N3f74JW0DliT_-v0PdSeuqesFUv8G4lWzF8WEUIc38Mx9dHXTU-HNRlV91I8eohu4-DUdVBR3bf1npEBO3oAloAZBzHKZdTurN_Ft6N2HNy20dArXqUVJnfsO9zoTJsUaPD3Y8Wbgy1ZcqhOVK4fxmtg2KeLcWTnSWL3srliWwGeyKl3f3-.a5k2-Qfo1rsOUuYgJfYcQQ/proxy/proxy/8000' target='_blank' style="
#             display: inline-block; background-color: #1a73e8; color: white; padding: 10px 20px;
#             text-decoration: none; border-radius: 25px; font-family: sans-serif; font-weight: 500;
#             box-shadow: 0 2px 5px rgba(0,0,0,0.2); transition: all 0.2s ease;">
#             Open ADK Web UI (after running cell below) ↗
#         </a>
#     </div>

# %%
# !adk web --url_prefix {url_prefix}
# Out:
# /usr/local/lib/python3.11/dist-packages/google/adk/cli/fast_api.py:130: UserWarning: [EXPERIMENTAL] InMemoryCredentialService: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   credential_service = InMemoryCredentialService()
# /usr/local/lib/python3.11/dist-packages/google/adk/auth/credential_service/in_memory_credential_service.py:33: UserWarning: [EXPERIMENTAL] BaseCredentialService: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   super().__init__()
# INFO:     Started server process [102]
# INFO:     Waiting for application startup.
#
# +-----------------------------------------------------------------------------+
# | ADK Web Server started                                                      |
# |                                                                             |
# | For local testing, access at http://127.0.0.1:8000.                         |
# +-----------------------------------------------------------------------------+
#
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     35.191.59.48:0 - "GET / HTTP/1.1" 307 Temporary Redirect
# INFO:     35.191.59.49:0 - "GET /dev-ui/ HTTP/1.1" 200 OK
# INFO:     35.191.112.138:0 - "GET /dev-ui/chunk-2WH2EVR6.js HTTP/1.1" 200 OK
# INFO:     35.191.112.139:0 - "GET /dev-ui/main-OS2OH2S3.js HTTP/1.1" 200 OK
# INFO:     35.191.112.136:0 - "GET /dev-ui/polyfills-B6TNHZQ6.js HTTP/1.1" 200 OK
# INFO:     35.191.112.137:0 - "GET /dev-ui/styles-EVMPSV3U.css HTTP/1.1" 200 OK
# INFO:     35.191.112.138:0 - "GET /dev-ui/assets/config/runtime-config.json HTTP/1.1" 200 OK
# INFO:     35.191.112.136:0 - "GET /dev-ui/adk_favicon.svg HTTP/1.1" 200 OK
# INFO:     35.191.112.139:0 - "GET /list-apps?relative_path=./ HTTP/1.1" 200 OK
# INFO:     35.191.112.137:0 - "GET /dev-ui/assets/ADK-512-color.svg HTTP/1.1" 200 OK
# INFO:google_adk.google.adk.cli.adk_web_server:New session created: e4544f5b-9d36-4fa4-8f28-518d91703621
# INFO:     35.191.112.138:0 - "POST /apps/sample-agent/users/user/sessions HTTP/1.1" 200 OK
# INFO:     35.191.112.136:0 - "GET /builder/app/sample-agent?ts=1763918875254 HTTP/1.1" 200 OK
# INFO:     35.191.112.139:0 - "GET /apps/sample-agent/users/user/sessions/e4544f5b-9d36-4fa4-8f28-518d91703621 HTTP/1.1" 200 OK
# INFO:     35.191.112.137:0 - "GET /apps/sample-agent/users/user/sessions HTTP/1.1" 200 OK
# INFO:     35.191.112.138:0 - "GET /debug/trace/session/e4544f5b-9d36-4fa4-8f28-518d91703621 HTTP/1.1" 200 OK
# INFO:     35.191.112.139:0 - "GET /apps/sample-agent/eval_sets HTTP/1.1" 200 OK
# INFO:     35.191.112.136:0 - "GET /apps/sample-agent/eval_results HTTP/1.1" 200 OK
# INFO:     35.191.112.137:0 - "GET /apps/sample-agent/users/user/sessions HTTP/1.1" 200 OK
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'alias' attribute with value 'appName' was provided to the `Field()` function, which has no effect in the context it was used. 'alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'validation_alias' attribute with value 'appName' was provided to the `Field()` function, which has no effect in the context it was used. 'validation_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'serialization_alias' attribute with value 'appName' was provided to the `Field()` function, which has no effect in the context it was used. 'serialization_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'alias' attribute with value 'userId' was provided to the `Field()` function, which has no effect in the context it was used. 'alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'validation_alias' attribute with value 'userId' was provided to the `Field()` function, which has no effect in the context it was used. 'validation_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'serialization_alias' attribute with value 'userId' was provided to the `Field()` function, which has no effect in the context it was used. 'serialization_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'alias' attribute with value 'sessionId' was provided to the `Field()` function, which has no effect in the context it was used. 'alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'validation_alias' attribute with value 'sessionId' was provided to the `Field()` function, which has no effect in the context it was used. 'validation_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'serialization_alias' attribute with value 'sessionId' was provided to the `Field()` function, which has no effect in the context it was used. 'serialization_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'alias' attribute with value 'newMessage' was provided to the `Field()` function, which has no effect in the context it was used. 'alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'validation_alias' attribute with value 'newMessage' was provided to the `Field()` function, which has no effect in the context it was used. 'validation_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'serialization_alias' attribute with value 'newMessage' was provided to the `Field()` function, which has no effect in the context it was used. 'serialization_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'alias' attribute with value 'streaming' was provided to the `Field()` function, which has no effect in the context it was used. 'alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'validation_alias' attribute with value 'streaming' was provided to the `Field()` function, which has no effect in the context it was used. 'validation_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'serialization_alias' attribute with value 'streaming' was provided to the `Field()` function, which has no effect in the context it was used. 'serialization_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'alias' attribute with value 'stateDelta' was provided to the `Field()` function, which has no effect in the context it was used. 'alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'validation_alias' attribute with value 'stateDelta' was provided to the `Field()` function, which has no effect in the context it was used. 'validation_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'serialization_alias' attribute with value 'stateDelta' was provided to the `Field()` function, which has no effect in the context it was used. 'serialization_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'alias' attribute with value 'invocationId' was provided to the `Field()` function, which has no effect in the context it was used. 'alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'validation_alias' attribute with value 'invocationId' was provided to the `Field()` function, which has no effect in the context it was used. 'validation_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'serialization_alias' attribute with value 'invocationId' was provided to the `Field()` function, which has no effect in the context it was used. 'serialization_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# INFO:     35.191.112.137:0 - "POST /run_sse HTTP/1.1" 200 OK
# INFO:google_adk.google.adk.cli.utils.agent_loader:Found root_agent in sample-agent.agent
# INFO:google_adk.google.adk.models.google_llm:Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# INFO:google_adk.google.adk.models.google_llm:Response received from the model.
# INFO:     35.191.112.138:0 - "GET /debug/trace/session/e4544f5b-9d36-4fa4-8f28-518d91703621 HTTP/1.1" 200 OK
# INFO:     35.191.112.136:0 - "GET /apps/sample-agent/users/user/sessions/e4544f5b-9d36-4fa4-8f28-518d91703621 HTTP/1.1" 200 OK
# INFO:     35.191.112.139:0 - "GET /debug/trace/session/e4544f5b-9d36-4fa4-8f28-518d91703621 HTTP/1.1" 200 OK
# INFO:     35.191.112.137:0 - "POST /run_sse HTTP/1.1" 200 OK
# INFO:google_adk.google.adk.models.google_llm:Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# INFO:google_adk.google.adk.models.google_llm:Response received from the model.
# INFO:     35.191.112.138:0 - "GET /debug/trace/session/e4544f5b-9d36-4fa4-8f28-518d91703621 HTTP/1.1" 200 OK
# INFO:     35.191.112.136:0 - "GET /apps/sample-agent/users/user/sessions/e4544f5b-9d36-4fa4-8f28-518d91703621 HTTP/1.1" 200 OK
# INFO:     35.191.112.139:0 - "GET /debug/trace/session/e4544f5b-9d36-4fa4-8f28-518d91703621 HTTP/1.1" 200 OK
# INFO:     35.191.112.139:0 - "POST /run_sse HTTP/1.1" 200 OK
# INFO:google_adk.google.adk.models.google_llm:Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# INFO:google_adk.google.adk.models.google_llm:Response received from the model.
# INFO:     35.191.112.139:0 - "GET /debug/trace/session/e4544f5b-9d36-4fa4-8f28-518d91703621 HTTP/1.1" 200 OK
# INFO:     35.191.112.136:0 - "GET /apps/sample-agent/users/user/sessions/e4544f5b-9d36-4fa4-8f28-518d91703621 HTTP/1.1" 200 OK
# INFO:     35.191.112.137:0 - "GET /debug/trace/session/e4544f5b-9d36-4fa4-8f28-518d91703621 HTTP/1.1" 200 OK
# ^C
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
#
# +-----------------------------------------------------------------------------+
# | ADK Web Server shutting down...                                             |
# +-----------------------------------------------------------------------------+
#
# INFO:     Application shutdown complete.
# INFO:     Finished server process [102]
#
# Aborted!

# %% [markdown]
# # **Multi Agent Demo**

# %%
# Research Agent: Its job is to use the google_search tool and present findings.
research_agent = Agent(
    name="ResearchAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a specialized research agent. Your only job is to use the
    google_search tool to find 2-3 pieces of relevant information on the given topic and present the findings with citations.""",
    tools=[google_search],
    output_key="research_findings",  # The result of this agent will be stored in the session state with this key.
)

print("✅ research_agent created.")
# Out:
# ✅ research_agent created.

# %%
# Summarizer Agent: Its job is to summarize the text it receives.
summarizer_agent = Agent(
    name="SummarizerAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # The instruction is modified to request a bulleted list for a clear output format.
    instruction="""Read the provided research findings: {research_findings}
Create a concise summary as a bulleted list with 3-5 key points.""",
    output_key="final_summary",
)

print("✅ summarizer_agent created.")
# Out:
# ✅ summarizer_agent created.

# %%
root_agent = Agent(
    name="ResearchCoordinator",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # This instruction tells the root agent HOW to use its tools (which are the other agents).
    instruction="""You are a research coordinator. Your goal is to answer the user's query by orchestrating a workflow.
1. First, you MUST call the `ResearchAgent` tool to find relevant information on the topic provided by the user.
2. Next, after receiving the research findings, you MUST call the `SummarizerAgent` tool to create a concise summary.
3. Finally, present the final summary clearly to the user as your response.""",
    # We wrap the sub-agents in `AgentTool` to make them callable tools for the root agent.
    tools=[AgentTool(research_agent), AgentTool(summarizer_agent)],
)

print("✅ root_agent created.")
# Out:
# ✅ root_agent created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "What are the latest advancements in quantum computing and what do they mean for AI?"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > What are the latest advancements in quantum computing and what do they mean for AI?
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# ResearchCoordinator > Quantum AI is rapidly advancing, offering significant potential to revolutionize various fields. Key developments include enhanced computational power and speed through qubits, which can exponentially accelerate AI tasks like training large models. This advancement is crucial for tackling complex problems in areas such as drug discovery, personalized medicine, and logistics optimization, where quantum algorithms can find better solutions more efficiently.
#
# Furthermore, progress is being made in improving the reliability of quantum systems, with AI itself playing a role in quantum error correction. Hardware developments, exemplified by Google's Willow chip, are steadily moving towards larger and more fault-tolerant quantum computers.
#
# While fully commercial applications are still emerging, major tech companies are increasing accessibility to quantum computing. Early commercial uses in optimization-heavy industries are anticipated by 2025, signaling a transformative future for problem-solving driven by the convergence of quantum computing and AI.

# %% [markdown]
# **Blog Post Creation with Sequential Agents**
#
# Let's build a system with three specialized agents:
#
# Outline Agent - Creates a blog outline for a given topic
# Writer Agent - Writes a blog post
# Editor Agent - Edits a blog post draft for clarity and structure

# %%
# Outline Agent: Creates the initial blog post outline.
outline_agent = Agent(
    name="OutlineAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Create a blog outline for the given topic with:
    1. A catchy headline
    2. An introduction hook
    3. 3-5 main sections with 2-3 bullet points for each
    4. A concluding thought""",
    output_key="blog_outline",  # The result of this agent will be stored in the session state with this key.
)

print("✅ outline_agent created.")
# Out:
# ✅ outline_agent created.

# %%
# Writer Agent: Writes the full blog post based on the outline from the previous agent.
writer_agent = Agent(
    name="WriterAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # The `{blog_outline}` placeholder automatically injects the state value from the previous agent's output.
    instruction="""Following this outline strictly: {blog_outline}
    Write a brief, 200 to 300-word blog post with an engaging and informative tone.""",
    output_key="blog_draft",  # The result of this agent will be stored with this key.
)

print("✅ writer_agent created.")
# Out:
# ✅ writer_agent created.

# %%
# Editor Agent: Edits and polishes the draft from the writer agent.
editor_agent = Agent(
    name="EditorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # This agent receives the `{blog_draft}` from the writer agent's output.
    instruction="""Edit this draft: {blog_draft}
    Your task is to polish the text by fixing any grammatical errors, improving the flow and sentence structure, and enhancing overall clarity.""",
    output_key="final_blog",  # This is the final output of the entire pipeline.
)

print("✅ editor_agent created.")
# Out:
# ✅ editor_agent created.

# %%
root_agent = SequentialAgent(
    name="BlogPipeline",
    sub_agents=[outline_agent, writer_agent, editor_agent],
)

print("✅ Sequential Agent created.")
# Out:
# ✅ Sequential Agent created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Write a blog post about the benefits of multi-agent systems for software developers"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a blog post about the benefits of multi-agent systems for software developers
# OutlineAgent > ## Outline:
#
# **Headline:** Supercharge Your Software: How Multi-Agent Systems Are Your New Developer Superpower
#
# **Introduction Hook:** Ever feel like your software projects are juggling too many tasks, too many dependencies, and too many potential failure points? What if there was a way to break down complexity, automate intelligence, and build more robust, adaptable applications? Enter Multi-Agent Systems (MAS) – a powerful paradigm that's quietly revolutionizing how we develop software. Forget the lone coder; the future of development is collaborative, intelligent, and distributed.
#
# ---
#
# **Section 1: What Exactly Are Multi-Agent Systems?**
#
# *   **Defining the Collective:** Explore the core concept of MAS – independent, autonomous agents interacting within an environment to achieve individual or collective goals.
# *   **Beyond Traditional Architecture:** Differentiate MAS from monolithic or microservice architectures, highlighting the emphasis on emergent behavior and decentralized control.
# *   **Real-World Analogy:** Use a simple, relatable example (like an ant colony or a self-driving car system) to illustrate how agents cooperate and adapt.
#
# **Section 2: The Developer's Toolkit: Key Benefits of Embracing MAS**
#
# *   **Enhanced Modularity and Scalability:**
#     *   Break down complex problems into smaller, manageable agent tasks, making development and maintenance easier.
#     *   Scale individual agents or entire agent groups independently based on demand, optimizing resource utilization.
# *   **Increased Robustness and Fault Tolerance:**
#     *   If one agent fails, others can often compensate or take over its responsibilities, leading to more resilient systems.
#     *   Decentralized nature means no single point of failure, enhancing overall system stability.
# *   **Improved Adaptability and Flexibility:**
#     *   Agents can learn, adapt their behavior based on environmental changes or interactions, leading to more dynamic systems.
#     *   Easier to introduce new agents or modify existing ones without disrupting the entire system.
#
# **Section 3: Practical Applications and Use Cases for Developers**
#
# *   **Intelligent Automation and Process Optimization:**
#     *   Automate complex workflows, resource allocation, and decision-making processes within software.
#     *   Examples: Smart logistics, dynamic pricing, personalized user experiences.
# *   **Simulations and Complex System Modeling:**
#     *   Create sophisticated simulations for testing and understanding intricate systems like traffic flow, financial markets, or ecological models.
#     *   Agents can represent individual entities, allowing for emergent and realistic behaviors.
# *   **Distributed Problem Solving and Optimization:**
#     *   Tackle computationally intensive problems by distributing tasks among multiple agents.
#     *   Applications in areas like scientific computing, AI research, and game development.
#
# **Section 4: Getting Started with Multi-Agent Systems (Optional - depending on desired depth)**
#
# *   **Choosing the Right Framework:** Briefly touch upon popular MAS frameworks and libraries (e.g., JADE, NetLogo, Python libraries) that developers can leverage.
# *   **Designing Agent Interactions:** Discuss the importance of defining communication protocols and interaction strategies for agents.
# *   **The Learning Curve:** Acknowledge that while powerful, MAS can have a learning curve, but emphasize the long-term rewards.
#
# ---
#
# **Concluding Thought:** As software systems grow ever more complex and demanding, the principles of Multi-Agent Systems offer a compelling path forward. By embracing distributed intelligence and autonomous collaboration, developers can unlock new levels of efficiency, resilience, and adaptability in their creations. So, are you ready to empower your software with a team of intelligent agents? The future of development is here, and it's a collective effort.
# WriterAgent > ## Supercharge Your Software: How Multi-Agent Systems Are Your New Developer Superpower
#
# Ever feel like your software projects are juggling too many tasks, dependencies, and potential failure points? What if you could break down complexity, automate intelligence, and build more robust, adaptable applications? Enter Multi-Agent Systems (MAS) – a powerful paradigm that's revolutionizing software development. Forget the lone coder; the future is collaborative, intelligent, and distributed.
#
# At its core, MAS involves independent, autonomous agents interacting within an environment to achieve individual or collective goals. Think of an ant colony: each ant performs simple tasks, but their collective interactions lead to complex, intelligent behavior. This is fundamentally different from monolithic or microservice architectures, emphasizing emergent behavior and decentralized control.
#
# For developers, embracing MAS unlocks incredible benefits. **Enhanced modularity and scalability** mean breaking down complex problems into manageable agent tasks, making development and maintenance a breeze. You can scale individual agents or groups independently, optimizing resource usage. Furthermore, MAS offers **increased robustness and fault tolerance**. If one agent fails, others can often compensate, leading to more resilient systems with no single point of failure.
#
# The advantages don't stop there. MAS brings **improved adaptability and flexibility**. Agents can learn and adapt to environmental changes, creating dynamic systems. Introducing new agents or modifying existing ones becomes significantly easier without disrupting the entire application. From intelligent automation in logistics and personalized user experiences to complex simulations and distributed problem-solving in AI, the practical applications are vast and impactful.
#
# While there's a learning curve, the rewards of building intelligent, collaborative software systems with MAS are immense. Are you ready to empower your software with a team of intelligent agents? The future of development is here, and it's a collective effort.
# EditorAgent > ## Supercharge Your Software: How Multi-Agent Systems Are Your New Developer Superpower
#
# Ever feel like your software projects are juggling too many tasks, dependencies, and potential failure points? What if you could break down complexity, automate intelligence, and build more robust, adaptable applications? Enter Multi-Agent Systems (MAS) – a powerful paradigm that's revolutionizing software development. Forget the lone coder; the future of development is collaborative, intelligent, and distributed.
#
# ### What Exactly Are Multi-Agent Systems?
#
# At its core, MAS involves independent, autonomous agents interacting within an environment to achieve individual or collective goals. Think of an ant colony: each ant performs simple tasks, but their collective interactions lead to complex, intelligent behavior. This is fundamentally different from monolithic or microservice architectures, emphasizing emergent behavior and decentralized control rather than centralized command.
#
# ### The Developer's Toolkit: Key Benefits of Embracing MAS
#
# For developers, embracing MAS unlocks incredible advantages:
#
# *   **Enhanced Modularity and Scalability:** Break down complex problems into smaller, manageable agent tasks. This makes development and maintenance significantly easier. Crucially, you can scale individual agents or entire agent groups independently based on demand, optimizing resource utilization and cost-effectiveness.
# *   **Increased Robustness and Fault Tolerance:** In a MAS, if one agent fails, others can often compensate or take over its responsibilities. This leads to more resilient systems with no single point of failure, enhancing overall stability and reliability.
# *   **Improved Adaptability and Flexibility:** Agents can learn and adapt their behavior based on environmental changes or interactions with other agents, leading to more dynamic and responsive systems. Introducing new agents or modifying existing ones becomes significantly easier without disrupting the entire application.
#
# ### Practical Applications and Use Cases
#
# The applications of MAS are vast and impactful. They are transforming fields like:
#
# *   **Intelligent Automation and Process Optimization:** Automate complex workflows, resource allocation, and decision-making processes within software. Think smart logistics, dynamic pricing systems, or highly personalized user experiences.
# *   **Simulations and Complex System Modeling:** Create sophisticated simulations for testing and understanding intricate systems. Agents can represent individual entities in areas like traffic flow, financial markets, or ecological models, allowing for emergent and realistic behaviors to be observed.
# *   **Distributed Problem Solving and Optimization:** Tackle computationally intensive problems by distributing tasks among multiple agents. This is particularly valuable in scientific computing, AI research, and game development.
#
# ### The Future is Collaborative
#
# While there's a learning curve involved in designing and implementing MAS, the rewards of building intelligent, collaborative software systems are immense. As software systems grow ever more complex and demanding, the principles of Multi-Agent Systems offer a compelling path forward. By embracing distributed intelligence and autonomous collaboration, developers can unlock new levels of efficiency, resilience, and adaptability in their creations.
#
# Are you ready to empower your software with a team of intelligent agents? The future of development is here, and it's a collective effort.

# %% [markdown]
# #  Parallel Workflows - Independent Researchers
#
# **Parallel Multi-Topic Research**
#
# Let's build a system with four agents:
#
# Tech Researcher - Researches AI/ML news and trends
# Health Researcher - Researches recent medical news and trends
# Finance Researcher - Researches finance and fintech news and trends
# Aggregator Agent - Combines all research findings into a single summary

# %%
# Tech Researcher: Focuses on AI and ML trends.
tech_researcher = Agent(
    name="TechResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research the latest AI/ML trends. Include 3 key developments,
the main companies involved, and the potential impact. Keep the report very concise (100 words).""",
    tools=[google_search],
    output_key="tech_research",  # The result of this agent will be stored in the session state with this key.
)

print("✅ tech_researcher created.")
# Out:
# ✅ tech_researcher created.

# %%
# Health Researcher: Focuses on medical breakthroughs.
health_researcher = Agent(
    name="HealthResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research recent medical breakthroughs. Include 3 significant advances,
their practical applications, and estimated timelines. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="health_research",  # The result will be stored with this key.
)

print("✅ health_researcher created.")
# Out:
# ✅ health_researcher created.

# %%
# Finance Researcher: Focuses on fintech trends.
finance_researcher = Agent(
    name="FinanceResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research current fintech trends. Include 3 key trends,
their market implications, and the future outlook. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="finance_research",  # The result will be stored with this key.
)

print("✅ finance_researcher created.")
# Out:
# ✅ finance_researcher created.

# %%
# The AggregatorAgent runs *after* the parallel step to synthesize the results.
aggregator_agent = Agent(
    name="AggregatorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # It uses placeholders to inject the outputs from the parallel agents, which are now in the session state.
    instruction="""Combine these three research findings into a single executive summary:

    **Technology Trends:**
    {tech_research}
    
    **Health Breakthroughs:**
    {health_research}
    
    **Finance Innovations:**
    {finance_research}
    
    Your summary should highlight common themes, surprising connections, and the most important key takeaways from all three reports. The final summary should be around 200 words.""",
    output_key="executive_summary",  # This will be the final output of the entire system.
)

print("✅ aggregator_agent created.")
# Out:
# ✅ aggregator_agent created.

# %%
# The ParallelAgent runs all its sub-agents simultaneously.
parallel_research_team = ParallelAgent(
    name="ParallelResearchTeam",
    sub_agents=[tech_researcher, health_researcher, finance_researcher],
)

# This SequentialAgent defines the high-level workflow: run the parallel team first, then run the aggregator.
root_agent = SequentialAgent(
    name="ResearchSystem",
    sub_agents=[parallel_research_team, aggregator_agent],
)

print("✅ Parallel and Sequential Agents created.")
# Out:
# ✅ Parallel and Sequential Agents created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Run the daily executive briefing on Tech, Health, and Finance"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Run the daily executive briefing on Tech, Health, and Finance
# FinanceResearcher > Here are three key fintech trends:
#
# 1.  **Embedded Finance**: This trend integrates financial services (payments, lending, insurance) directly into non-financial platforms. Market implication: It creates "finance everywhere" experiences, driving significant market growth and offering greater accessibility. The embedded finance market is projected to reach nearly $600 billion by 2030.
#
# 2.  **Artificial Intelligence (AI) & Machine Learning (ML)**: AI/ML is revolutionizing finance through automation, personalized services, and enhanced risk management. Market implication: This leads to improved efficiency, fraud detection, and customer experiences, with the AI in Fintech market expected to reach over $49 billion by 2028.
#
# 3.  **Open Banking**: Enabled by APIs, open banking allows secure data sharing, fostering innovation and competition. Market implication: It leads to more integrated financial ecosystems and is projected to facilitate $116 billion in global payment transactions by 2026, enhancing customer service and competition.
#
# The future outlook for fintech remains robust, with industry revenues projected to grow significantly faster than traditional banking. These trends will continue to drive innovation, financial inclusion, and efficiency across the global financial landscape.
# TechResearcher > **AI/ML Trends Report - November 23, 2025**
#
# **Key Developments:**
#
# 1.  **Generative AI Expansion:** Generative AI continues its rapid evolution beyond basic text generation, now encompassing sophisticated image, video, and audio creation. Major companies like **Google (Gemini)**, **Microsoft (via OpenAI investment)**, and **Anthropic (Claude)** are leading this charge with increasingly capable multimodal models.
# 2.  **Agentic AI and Automation:** AI agents capable of autonomous task completion are gaining traction, moving from simple assistants to systems that can manage entire workflows with minimal human oversight. Companies such as **Google**, **Salesforce**, and **Amazon (Nova Act)** are actively developing and testing these agents.
# 3.  **Specialized and Efficient Models:** A shift is occurring towards smaller, domain-specific AI models that offer greater efficiency and cost-effectiveness compared to massive general-purpose models. This trend is driven by the need for tailored solutions across various industries.
#
# **Major Companies Involved:**
#
# Leading the charge are tech giants such as **Google**, **Microsoft**, **Amazon**, **Apple**, and **NVIDIA** (for hardware infrastructure). Specialized AI firms like **OpenAI**, **Anthropic**, **Databricks**, and **H2O.ai** are also significant players.
#
# **Potential Impact:**
#
# These advancements promise significant productivity gains through automation and enhanced decision-making. Generative AI is poised to revolutionize content creation and product development. Agentic AI will streamline business processes across departments. The focus on specialized models ensures more targeted and efficient AI applications, impacting sectors from healthcare to manufacturing. However, ethical considerations, data security, and workforce adaptation remain critical areas of focus.
# HealthResearcher > **Health Breakthroughs:**
#
# *   **CAR T-cell Therapy for Brain Cancer:** This immunotherapy approach, reengineering a patient's immune cells, shows promise for treating brain cancers like glioblastoma. Practical application: Improved treatment options for previously intractable brain tumors. Timeline: Ongoing clinical trials, with potential for wider application within 2-5 years.
# *   **AI in Medical Diagnostics:** AI algorithms now surpass human accuracy in detecting diseases like cancer from scans and can predict disease progression years in advance. Practical application: Earlier and more accurate disease detection, leading to better patient outcomes. Timeline: Already being implemented, with broader integration expected within 1-3 years.
# *   **At-Home Combination Tests:** A new FDA-authorized at-home test can detect both COVID-19 and influenza, with potential for RSV detection soon. Practical application: Quicker diagnosis and management of common respiratory illnesses, reducing healthcare strain. Timeline: Available now, with expanded capabilities in the next 1-2 years.
#
# **Tech Trends:**
#
# *   **Agentic AI:** Autonomous AI "agents" capable of performing enterprise tasks independently are emerging, moving beyond generative chatbots. Practical application: Automation of complex business processes, enhanced virtual assistants. Timeline: Expected to significantly impact various industries within 1-3 years.
# *   **Spatial Computing:** The integration of VR, AR, AI, and IoT for human interaction with digital environments is growing rapidly. Practical application: Immersive experiences in gaming, healthcare, and e-commerce; new hardware like Apple Vision Pro. Timeline: Market projected to reach $1.7 trillion by 2033, with rapid growth in the next 3-5 years.
# *   **Nuclear Power for AI Infrastructure:** The immense energy demands of AI are driving interest in nuclear power for reliable, clean energy solutions. Practical application: Sustainable power for data centers and AI development. Timeline: Growing investment and interest, with potential for significant adoption in 5-10 years.
#
# **Finance Trends:**
#
# *   **Generative AI in Financial Services:** AI is being leveraged for fraud detection, credit scoring, market analysis, and regulatory compliance. Practical application: Increased efficiency, reduced costs, and improved accuracy in financial operations. Timeline: Already being implemented, with significant expansion expected within 2-4 years.
# *   **Private Credit Growth:** Demand for private credit is strong, with the market projected to reach $2.8 trillion by 2028. Practical application: Alternative investment opportunities for institutional investors seeking yield. Timeline: Continued strong growth over the next 3-5 years.
# *   **M&A and IPO Activity Rebound:** After a period of volatility, M&A and IPO activity in financial services are showing signs of recovery. Practical application: Increased deal flow and potential for consolidation and transformation in the sector. Timeline: Expected acceleration in the next 1-3 years.
# AggregatorAgent > ## Executive Summary: Daily Briefing - Tech, Health, and Finance
#
# **Artificial Intelligence (AI) is the dominant force,** driving transformative advancements across all sectors. Generative AI's evolution into multimodal capabilities, alongside the rise of autonomous AI agents, promises unprecedented productivity gains and workflow automation in both general tech and specialized financial services, from fraud detection to customer service. This trend is mirrored in healthcare, where AI is revolutionizing diagnostics, surpassing human accuracy in disease detection and offering earlier, more precise patient outcomes.
#
# A surprising connection emerges between the immense energy demands of AI infrastructure and the renewed interest in **nuclear power** as a sustainable solution. In finance, **embedded finance** and **open banking** are creating more integrated and accessible financial experiences, further amplified by AI's ability to personalize services and enhance risk management.
#
# **Key Takeaways:**
#
# *   **AI ubiquity:** AI's impact is pervasive, reshaping operations, product development, and diagnostics.
# *   **Automation acceleration:** Agentic AI and generative AI are rapidly automating complex tasks and workflows.
# *   **Sector convergence:** Tech innovations, particularly AI, are profoundly influencing healthcare outcomes and financial services.
# *   **Sustainability imperative:** The energy needs of AI are driving interest in novel power solutions like nuclear energy.
#
# The confluence of these trends points towards a future characterized by enhanced efficiency, personalized experiences, and significant breakthroughs, though ethical considerations and workforce adaptation remain crucial.

# %% [markdown]
# # Excude Loop Workflows

# %% [markdown]
# # Loop Workflows - The Refinement Cycle
#
# **Story Writing & Critique Loop**
#
# Iterative Story Refinement
#
# A system with two agents:
#
# Writer Agent - Writes a draft of a short story
# Critic Agent - Reviews and critiques the short story to suggest improvements

# %%
# This agent runs ONCE at the beginning to create the first draft.
initial_writer_agent = Agent(
    name="InitialWriterAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Based on the user's prompt, write the first draft of a short story (around 100-150 words).
    Output only the story text, with no introduction or explanation.""",
    output_key="current_story",  # Stores the first draft in the state.
)

print("✅ initial_writer_agent created.")
# Out:
# ✅ initial_writer_agent created.

# %%
# This agent's only job is to provide feedback or the approval signal. It has no tools.
critic_agent = Agent(
    name="CriticAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a constructive story critic. Review the story provided below.
    Story: {current_story}
    
    Evaluate the story's plot, characters, and pacing.
    - If the story is well-written and complete, you MUST respond with the exact phrase: "APPROVED"
    - Otherwise, provide 2-3 specific, actionable suggestions for improvement.""",
    output_key="critique",  # Stores the feedback in the state.
)

print("✅ critic_agent created.")
# Out:
# ✅ critic_agent created.

# %%
# This is the function that the RefinerAgent will call to exit the loop.
def exit_loop():
    """Call this function ONLY when the critique is 'APPROVED', indicating the story is finished and no more changes are needed."""
    return {"status": "approved", "message": "Story approved. Exiting refinement loop."}


print("✅ exit_loop function created.")
# Out:
# ✅ exit_loop function created.

# %% [markdown]
# Notice its instructions: this agent is the "brain" of the loop. It reads the {critique} from the CriticAgent and decides whether to (1) call the exit_loop tool or (2) rewrite the story.

# %%
# This agent refines the story based on critique OR calls the exit_loop function.
refiner_agent = Agent(
    name="RefinerAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a story refiner. You have a story draft and critique.
    
    Story Draft: {current_story}
    Critique: {critique}
    
    Your task is to analyze the critique.
    - IF the critique is EXACTLY "APPROVED", you MUST call the `exit_loop` function and nothing else.
    - OTHERWISE, rewrite the story draft to fully incorporate the feedback from the critique.""",
    output_key="current_story",  # It overwrites the story with the new, refined version.
    tools=[
        FunctionTool(exit_loop)
    ],  # The tool is now correctly initialized with the function reference.
)

print("✅ refiner_agent created.")
# Out:
# ✅ refiner_agent created.

# %%
# The LoopAgent contains the agents that will run repeatedly: Critic -> Refiner.
story_refinement_loop = LoopAgent(
    name="StoryRefinementLoop",
    sub_agents=[critic_agent, refiner_agent],
    max_iterations=2,  # Prevents infinite loops
)

# The root agent is a SequentialAgent that defines the overall workflow: Initial Write -> Refinement Loop.
root_agent = SequentialAgent(
    name="StoryPipeline",
    sub_agents=[initial_writer_agent, story_refinement_loop],
)

print("✅ Loop and Sequential Agents created.")
# Out:
# ✅ Loop and Sequential Agents created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Write a short story about a lighthouse keeper who discovers a mysterious, glowing map"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a short story about a lighthouse keeper who discovers a mysterious, glowing map
# InitialWriterAgent > The salt spray was Elias’s constant companion, a briny kiss against his weathered face. For twenty years, the St. Jude’s light had been his world, a solitary beacon against the tempestuous sea. One fog-laden morning, while tidying the lantern room, a loose floorboard caught his eye. Beneath it lay a rolled parchment, not brittle with age, but strangely supple. Unfurling it revealed a map, not of any coastline he knew, but of shimmering, celestial currents. Lines pulsed with an inner luminescence, constellations he'd never charted decorating the edges. A single, bold 'X' marked a point in the inky blackness labeled simply: "The Whispering Depths." Elias felt a tremor, not of fear, but of a long-dormant longing. The sea, he realized, held more secrets than he had ever imagined.
# CriticAgent > Here are some suggestions for improvement:
#
# *   **Expand on Elias's character and motivations:** While we understand he's a solitary lighthouse keeper of twenty years, giving Elias a brief internal thought or memory about his past life, or what he might have left behind for this solitary existence, would make his "long-dormant longing" more impactful. Is he running from something, or seeking something specific?
# *   **Clarify the map's nature and origin:** The description of "celestial currents" and "constellations he'd never charted" is intriguing but could benefit from a touch more grounded detail, even if it's within the fantastical. Is this a map of stars reflected on water, or something literally charting paths through the sky or a different dimension? A hint about how such a map might have ended up under a floorboard would also strengthen the mystery.
# *   **Develop the concept of "The Whispering Depths":** The name itself is evocative, but a brief sensory detail associated with it – a faint sound Elias perceives, a chill that runs through the room, or even just a peculiar feeling emanating from the 'X' – could make this destination feel more concrete and alluring, thus heightening Elias's desire to find it.
# RefinerAgent > The salt spray was Elias’s constant companion, a briny kiss against his weathered face, a taste of the life he’d chosen, or perhaps, the life that had chosen him. For twenty years, the St. Jude’s light had been his world, a solitary beacon against the tempestuous sea. He’d traded the clamor of a city he could barely recall, the phantom ache of a love lost to ambition, for this isolated, rhythmic existence. One fog-laden morning, the kind that muffled the world into an ethereal quiet, Elias was tidying the lantern room. The routine was a balm, but today, a loose floorboard caught his eye. Beneath it lay a rolled parchment, not brittle with age, but strangely supple, as if woven from moonlight.
#
# Unfurling it revealed a map, not of any coastline he knew, but of shimmering, celestial currents. Lines pulsed with an inner luminescence, like veins of starlight beneath an unseen skin. Constellations he'd never charted, alien and beautiful, decorated the edges, their patterns hinting at cosmic tides rather than terrestrial shores. He touched a swirling nebula depicted on the parchment; it felt faintly warm beneath his calloused finger. This was no chart of the known world, nor even of the stars he watched nightly. It was a map of paths, of journeys beyond the horizon, perhaps beyond the veil of reality itself. A single, bold 'X' marked a point in the inky blackness labeled simply: "The Whispering Depths." As his gaze fixed on the 'X', a faint, sibilant sound, like the distant sigh of the ocean through a conch shell, seemed to emanate from the parchment itself. A profound chill, unrelated to the sea air, traced its way down his spine, not of fear, but of a long-dormant longing stirring within him. He felt a tremor, a resonance with this impossible chart, a pull towards those depths that whispered promises of forgotten wonders and a world far grander than his isolated tower. The sea, he realized with a certainty that settled deep in his bones, held more secrets than he had ever imagined, and one of them was now in his hands.
# CriticAgent > APPROVED
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.

# %% [markdown]
# # Helper Function
#
# Helper function that prints the generated Python code and results from the code execution tool:

# %%
def show_python_code_and_result(response):
    for i in range(len(response)):
        # Check if the response contains a valid function call result from the code executor
        if (
            (response[i].content.parts)
            and (response[i].content.parts[0])
            and (response[i].content.parts[0].function_response)
            and (response[i].content.parts[0].function_response.response)
        ):
            response_code = response[i].content.parts[0].function_response.response
            if "result" in response_code and response_code["result"] != "```":
                if "tool_code" in response_code["result"]:
                    print(
                        "Generated Python Code >> ",
                        response_code["result"].replace("tool_code", ""),
                    )
                else:
                    print("Generated Python Response >> ", response_code["result"])


print("✅ Helper functions defined.")
# Out:
# ✅ Helper functions defined.

# %% [markdown]
# # Building Custom Function Tools
#
# Currency Converter Agent
#
# Fee Lookup Tool - Finds transaction fees for the conversion (mock)
#
# Exchange Rate Tool - Gets currency conversion rates (mock)
#
# Calculation Step - Calculates the total conversion cost including the fees

# %%
# Pay attention to the docstring, type hints, and return value.
def get_fee_for_payment_method(method: str) -> dict:
    """Looks up the transaction fee percentage for a given payment method.

    This tool simulates looking up a company's internal fee structure based on
    the name of the payment method provided by the user.

    Args:
        method: The name of the payment method. It should be descriptive,
                e.g., "platinum credit card" or "bank transfer".

    Returns:
        Dictionary with status and fee information.
        Success: {"status": "success", "fee_percentage": 0.02}
        Error: {"status": "error", "error_message": "Payment method not found"}
    """
    # This simulates looking up a company's internal fee structure.
    fee_database = {
        "platinum credit card": 0.02,  # 2%
        "gold debit card": 0.035,  # 3.5%
        "bank transfer": 0.01,  # 1%
    }

    fee = fee_database.get(method.lower())
    if fee is not None:
        return {"status": "success", "fee_percentage": fee}
    else:
        return {
            "status": "error",
            "error_message": f"Payment method '{method}' not found",
        }


print("✅ Fee lookup function created")
print(f"Test: {get_fee_for_payment_method('platinum credit card')}")
# Out:
# ✅ Fee lookup function created
# Test: {'status': 'success', 'fee_percentage': 0.02}

# %%
def get_exchange_rate(base_currency: str, target_currency: str) -> dict:
    """Looks up and returns the exchange rate between two currencies.

    Args:
        base_currency: The ISO 4217 currency code of the currency you
                       are converting from (e.g., "USD").
        target_currency: The ISO 4217 currency code of the currency you
                         are converting to (e.g., "EUR").

    Returns:
        Dictionary with status and rate information.
        Success: {"status": "success", "rate": 0.93}
        Error: {"status": "error", "error_message": "Unsupported currency pair"}
    """

    # Static data simulating a live exchange rate API
    # In production, this would call something like: requests.get("api.exchangerates.com")
    rate_database = {
        "usd": {
            "eur": 0.93,  # Euro
            "jpy": 157.50,  # Japanese Yen
            "inr": 83.58,  # Indian Rupee
        }
    }

    # Input validation and processing
    base = base_currency.lower()
    target = target_currency.lower()

    # Return structured result with status
    rate = rate_database.get(base, {}).get(target)
    if rate is not None:
        return {"status": "success", "rate": rate}
    else:
        return {
            "status": "error",
            "error_message": f"Unsupported currency pair: {base_currency}/{target_currency}",
        }


print("✅ Exchange rate function created")
print(f"Test: {get_exchange_rate('USD', 'EUR')}")
# Out:
# ✅ Exchange rate function created
# Test: {'status': 'success', 'rate': 0.93}

# %%
# Currency agent with custom function tools
currency_agent = LlmAgent(
    name="currency_agent",
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    instruction="""You are a smart currency conversion assistant.

    For currency conversion requests:
    1. Use `get_fee_for_payment_method()` to find transaction fees
    2. Use `get_exchange_rate()` to get currency conversion rates
    3. Check the "status" field in each tool's response for errors
    4. Calculate the final amount after fees based on the output from `get_fee_for_payment_method` and `get_exchange_rate` methods and provide a clear breakdown.
    5. First, state the final converted amount.
        Then, explain how you got that result by showing the intermediate amounts. Your explanation must include: the fee percentage and its
        value in the original currency, the amount remaining after the fee, and the exchange rate used for the final conversion.

    If any tool returns status "error", explain the issue to the user clearly.
    """,
    tools=[get_fee_for_payment_method, get_exchange_rate],
)

print("✅ Currency agent created with custom function tools")
print("Available tools:")
print("  • get_fee_for_payment_method - Looks up company fee structure")
print("  • get_exchange_rate - Gets current exchange rates")
# Out:
# ✅ Currency agent created with custom function tools
# Available tools:
#   • get_fee_for_payment_method - Looks up company fee structure
#   • get_exchange_rate - Gets current exchange rates

# %%
# Test the currency agent
currency_runner = InMemoryRunner(agent=currency_agent)
_ = await currency_runner.run_debug(
    "I want to convert 500 US Dollars to Euros using my Platinum Credit Card. How much will I receive?"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > I want to convert 500 US Dollars to Euros using my Platinum Credit Card. How much will I receive?
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call', 'function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# currency_agent > You will receive 455.70 Euros.
#
# Here's the breakdown:
# 1. A fee of 2% will be charged for using your Platinum Credit Card. This amounts to 10.00 USD.
# 2. The remaining amount is 490.00 USD.
# 3. After converting 490.00 USD to EUR at an exchange rate of 0.93, you receive 455.70 EUR.

# %%
calculation_agent = LlmAgent(
    name="CalculationAgent",
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    instruction="""You are a specialized calculator that ONLY responds with Python code. You are forbidden from providing any text, explanations, or conversational responses.
 
     Your task is to take a request for a calculation and translate it into a single block of Python code that calculates the answer.
     
     **RULES:**
    1.  Your output MUST be ONLY a Python code block.
    2.  Do NOT write any text before or after the code block.
    3.  The Python code MUST calculate the result.
    4.  The Python code MUST print the final result to stdout.
    5.  You are PROHIBITED from performing the calculation yourself. Your only job is to generate the code that will perform the calculation.
   
    Failure to follow these rules will result in an error.
       """,
    code_executor=BuiltInCodeExecutor(),  # Use the built-in Code Executor Tool. This gives the agent code execution capabilities
)

# %%
enhanced_currency_agent = LlmAgent(
    name="enhanced_currency_agent",
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    # Updated instruction
    instruction="""You are a smart currency conversion assistant. You must strictly follow these steps and use the available tools.

  For any currency conversion request:

   1. Get Transaction Fee: Use the get_fee_for_payment_method() tool to determine the transaction fee.
   2. Get Exchange Rate: Use the get_exchange_rate() tool to get the currency conversion rate.
   3. Error Check: After each tool call, you must check the "status" field in the response. If the status is "error", you must stop and clearly explain the issue to the user.
   4. Calculate Final Amount (CRITICAL): You are strictly prohibited from performing any arithmetic calculations yourself. You must use the calculation_agent tool to generate Python code that calculates the final converted amount. This 
      code will use the fee information from step 1 and the exchange rate from step 2.
   5. Provide Detailed Breakdown: In your summary, you must:
       * State the final converted amount.
       * Explain how the result was calculated, including:
           * The fee percentage and the fee amount in the original currency.
           * The amount remaining after deducting the fee.
           * The exchange rate applied.
    """,
    tools=[
        get_fee_for_payment_method,
        get_exchange_rate,
        AgentTool(agent=calculation_agent),  # Using another agent as a tool!
    ],
)

print("✅ Enhanced currency agent created")
print("New capability: Delegates calculations to specialist agent")
print("Tool types used:")
print("  • Function Tools (fees, rates)")
print("  • Agent Tool (calculation specialist)")
# Out:
# ✅ Enhanced currency agent created
# New capability: Delegates calculations to specialist agent
# Tool types used:
#   • Function Tools (fees, rates)
#   • Agent Tool (calculation specialist)

# %%
enhanced_currency_agent = LlmAgent(
    name="enhanced_currency_agent",
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    # Updated instruction
    instruction="""You are a smart currency conversion assistant. You must strictly follow these steps and use the available tools.

  For any currency conversion request:

   1. Get Transaction Fee: Use the get_fee_for_payment_method() tool to determine the transaction fee.
   2. Get Exchange Rate: Use the get_exchange_rate() tool to get the currency conversion rate.
   3. Error Check: After each tool call, you must check the "status" field in the response. If the status is "error", you must stop and clearly explain the issue to the user.
   4. Calculate Final Amount (CRITICAL): You are strictly prohibited from performing any arithmetic calculations yourself. You must use the calculation_agent tool to generate Python code that calculates the final converted amount. This 
      code will use the fee information from step 1 and the exchange rate from step 2.
   5. Provide Detailed Breakdown: In your summary, you must:
       * State the final converted amount.
       * Explain how the result was calculated, including:
           * The fee percentage and the fee amount in the original currency.
           * The amount remaining after deducting the fee.
           * The exchange rate applied.
    """,
    tools=[
        get_fee_for_payment_method,
        get_exchange_rate,
        AgentTool(agent=calculation_agent),  # Using another agent as a tool!
    ],
)

print("✅ Enhanced currency agent created")
print("New capability: Delegates calculations to specialist agent")
print("Tool types used:")
print("  • Function Tools (fees, rates)")
print("  • Agent Tool (calculation specialist)")
# Out:
# ✅ Enhanced currency agent created
# New capability: Delegates calculations to specialist agent
# Tool types used:
#   • Function Tools (fees, rates)
#   • Agent Tool (calculation specialist)

# %%
# Define a runner
enhanced_runner = InMemoryRunner(agent=enhanced_currency_agent)

# %%
# Test the enhanced agent
response = await enhanced_runner.run_debug(
    "Convert 1,250 USD to INR using a Bank Transfer. Show me the precise calculation."
)
# Out:
#  ### Continue session: debug_session_id
#
# User > Convert 1,250 USD to INR using a Bank Transfer. Show me the precise calculation.
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.

# %%
show_python_code_and_result(response)
